# %% [markdown]
# ## Running OpenSource LLM  in Google Colab

# %% [markdown]
# py -m venv .venv
# .venv/Scripts/activate
# pip install -r package.txt
# pip freeze > package-lock.txt

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\dburk\documents\github\colab-opensource-llm\.venv\lib\site-packages (3.0.1)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\dburk\documents\github\colab-opensource-llm\.venv\lib\site-packages (from pandas) (2.4.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\dburk\documents\github\colab-opensource-llm\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\dburk\documents\github\colab-opensource-llm\.venv\lib\site-packages (from pandas) (2025.3)
# Requirement already satisfied: six>=1.5 in c:\users\dburk\documents\github\colab-opensource-llm\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
print("Hello, World!")
# Out:
# Hello, Colab!
